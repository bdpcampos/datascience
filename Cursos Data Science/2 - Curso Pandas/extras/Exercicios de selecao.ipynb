# %%
import pandas as pd

# %%
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
alunos.to_csv('dados/base_exercicios.csv', sep = ';', index = False)

# %%
alunos_aprovados = alunos[alunos['Aprovado']]
alunos_aprovados
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
selecao = (alunos['Aprovado'] == True) & (alunos['Sexo'] == 'F')
alunas_aprovadas = alunos[selecao]
alunas_aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
selecao_2 = (alunos['Idade'] >= 40) | ((alunos['Idade'] >= 10) & (alunos['Idade'] <= 20))
alunos[selecao_2]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 2   Denis     56    M    5.0     False
# 4   Bruna     42    F    8.2      True
# 6  Carlos     19    M    6.0     False

# %%
alunos_importacao = pd.DataFrame(pd.read_csv('dados/base_exercicios.csv', sep = ';'))
alunos_importacao
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
alunos_aprovados = alunos[alunos['Aprovado'] == False][['Nome', 'Sexo', 'Idade']]
alunos_aprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
alunos.sort_values(by = ['Idade'], inplace = True)
alunos.iloc[0:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True
